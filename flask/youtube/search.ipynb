# %%
from datetime import datetime

from apiclient.discovery import build
from apiclient.errors import HttpError
from oauth2client.tools import argparser

# %%
DEVELOPER_KEY = 'AIzaSyBUt2uRD7wvPWOm72P6ivTUljGfb-8F6gE'
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"


class Channel:
    
    def __init__(self, **kwargs):
        self.publishedAt= kwargs.get('publishedAt')
        self.channelId= kwargs.get('channelId')
        self.title= kwargs.get('title')
        self.description= kwargs.get('description')
        self.thumbnail= kwargs.get('thumbnail')

class PlayListItem:
    
    def __init__(self, **kwargs):
        self.Id = kwargs.get('id')
        self.publishedAt = kwargs.get('publishedAt')
        self.videoId= kwargs.get('videoId')
        self.title= kwargs.get('title')
        self.description= kwargs.get('description')
        self.thumbnail= kwargs.get('thumbnail')



def searchChannel(keyword):
    #해당 검색어로 관련된 채널 50개 반환
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
            developerKey=DEVELOPER_KEY)

    search_response = youtube.search().list(
            q=keyword,
            type="channel",
            part="id,snippet",
            maxResults=50
        ).execute()

    channels =[]

    for i in search_response['items']:
        result = i['snippet']
        
        attr = {
            'publishedAt' : result['publishedAt'],
            'channelId' : result['channelId'],
            'title' : result['title'],
            'description' : result['description'],
            'thumbnail' : result['thumbnails']['default']['url'],
        }

        channel = Channel(kwargs = attr)
        channels.append(channel)
    
    return channels


def searchPlaylistItems(playlistId):
    playlistItems =[]

    playlist_response = youtube.playlistItems().list(
            playlistId=playlistId,
            part="id,snippet",
            maxResults=50
        ).execute()

    playlistItems.extend(extractPlaylistItems(playlist_response))
    nextPageToken = playlist_response.get('nextPageToken', None)

    while nextPageToken:
        playlist_response = youtube.playlistItems().list(
            playlistId=playlistId,
            part="id,snippet",
            maxResults=50,
            pageToken= nextPageToken
        ).execute()

        playlistItems.append(extractPlaylistItems(playlist_response))
        nextPageToken = playlist_response.get('nextPageToken', None)
        
        playlistItems.extend(playlistItem)

    return playlistItems

def extractPlaylistItems(playlist_response):
    playlistItems =[]

    for row in playlist_response['items']:
        result = row['snippet']
        attr ={
            'id' : row['id'],
            'publishedAt': result['publishedAt'],
            'description': result['description'],
            'thumbnail': result['thumbnails']['default']['url'],
            'title': result['title'],
            'videoId': result['resourceId']['videoId'],
        }
        playlistItem = PlayListItem(kwargs = attr)
        playlistItems.append(playlistItem)

    return playlistItems

# %%
channelId = "UCUj6rrhMTR9pipbAWBAMvUQ"

channel_response = youtube.playlists().list(
        channelId=channelId,
        part="id,snippet",
        maxResults=50
    ).execute()

# %%
result =searchPlaylist(channelId)

# %%
channel_response = youtube.playlists().list(
        channelId=channelId,
        part="id,snippet",
        maxResults=50
    ).execute()
channel_response['pageInfo']
# Out:
# {'totalResults': 179, 'resultsPerPage': 50}

# %%
# channel Id 받아서 items 넘기기

playlistId = 'PLif_jr7pPZAAZDzqxatWiJecllbfRZMAX'

playlistItems =[]

playlist_response = youtube.playlistItems().list(
            playlistId=playlistId,
            part="id,snippet",
            maxResults=50
        ).execute()

playlist_response['pageInfo']

# %%
id, snippet, contentDetails, fileDetails, liveStreamingDetails, player, processingDetails, recordingDetails, statistics, status, suggestions, topicDetails

snippet.title
statistics.viewCount
statistics.dislikeCount
statistics.favoriteCount
statistics.commentCount

# %%
videoId ="RdlAPHwfkFQ"
video_response = youtube.videos().list(
            part="id,snippet,statistics",
            id=videoId,
            maxResults=50
        ).execute()

# %%
video_response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'HJdh-fFYTiuQF69uecXHG4CnmCA',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'mSvw7jZjXWDOJZv7Q7Uo9BAviUA',
#    'id': 'RdlAPHwfkFQ',
#    'snippet': {'publishedAt': '2016-09-07T07:51:59Z',
#     'channelId': 'UCUj6rrhMTR9pipbAWBAMvUQ',
#     'title': '【투 더 문】 #1 달에 가고 싶은 영감님 (To the moon)',
#     'description': "♨'투 더 문' 처음부터 보기: http://goo.gl/M59Wtb\n보시다가 재밌는 부분은 댓글로 제보해 주시면 하이라이트 영상에 반영하겠습니다. 감사합니다.\n\n2016년 9월 2일 방송분\n침착맨 유투부 구독하기: http://goo.gl/wzc7Ib\n침착맨 트위치 방송: http://www.twitch.tv/zilioner",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RdlAPHwfkFQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RdlAPHwfkFQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RdlAPHwfkFQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
# ...

# %%
video_response['items'][0]['statistics']
# Out:
# {'viewCount': '26809',
#  'likeCount': '138',
#  'dislikeCount': '8',
#  'favoriteCount': '0',
#  'commentCount': '43'}

# %%
channelId = "UCUj6rrhMTR9pipbAWBAMvUQ"
comment_reponse = youtube.commentThreads().list(
    part ="id,snippet",
    videoId= videoId , 
pageToken="QURTSl9pMl9ZMFM4SHFVT21TQzhKdUtsUlIxc2h4SVZPMjFkZFBEd2FseXNMRHNSNmdHUm9oTWpsWFVqS29YYVJsOGhnbjc2cEYzVzZfcw=="
).execute()

# %%
youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
            developerKey=DEVELOPER_KEY)
channelId = "UCUj6rrhMTR9pipbAWBAMvUQ"
channel_reponse = youtube.channels().list(
            part="id,snippet,statistics",
            id = channelId
        ).execute()

# %%
channel_reponse
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'HEAkYp-tUEQbG6SkSTinU-O5bfg',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'dqPXq9Sua3HJ_CqPZIF13pY7f4g',
#    'id': 'UCUj6rrhMTR9pipbAWBAMvUQ',
#    'snippet': {'title': '침착맨',
#     'description': '반갑습니다. 오늘도 즐거운 날입니다.',
#     'publishedAt': '2014-09-30T07:40:14Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AAUvwnip3m0vrondZ7foBbpk-voKKm7coZkTEqWkWmz8nw=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AAUvwnip3m0vrondZ7foBbpk-voKKm7coZkTEqWkWmz8nw=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AAUvwnip3m0vrondZ7foBbpk-voKKm7coZkTEqWkWmz8nw=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': '침착맨', 'description': '반갑습니다. 오늘도 즐거운 날입니다.'},
# ...

# %%
comment_reponse
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'L7fqaJrAiSsaM8Ho0DKW_0qZEtU',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'hOMY1WzxUrJv6Jy8wTFqqiEPfK4',
#    'id': 'UgjpNHGZSY-tC3gCoAEC',
#    'snippet': {'videoId': 'RdlAPHwfkFQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'e0uWXZdMvSaOZjilKdNt-P54ZZo',
#      'id': 'UgjpNHGZSY-tC3gCoAEC',
#      'snippet': {'videoId': 'RdlAPHwfkFQ',
#       'textDisplay': '노비타 바이오하자드 하시는 거 보고싶습니다 아재',
#       'textOriginal': '노비타 바이오하자드 하시는 거 보고싶습니다 아재',
#       'authorDisplayName': '오성택',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AAUvwngafl1BDvvv7OpNXOFhv7tOtQWTrae3_xtFLnla8Q=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCJc0q_R2nD34v6s3Xk-Bavg',
#       'authorChannelId': {'value': 'UCJc0q_R2nD34v6s3Xk-Bavg'},
#       'canRate': True,
#       'viewerRating': 'none',
# ...

# %%
video_response['items'][0]['statistics']
# Out:
# {'viewCount': '26809',
#  'likeCount': '138',
#  'dislikeCount': '8',
#  'favoriteCount': '0',
#  'commentCount': '43'}

# %%
for row in playlist_response['items']:
    print(row)
# Out:
# {'kind': 'youtube#playlistItem', 'etag': '9EXE_w3Db5a7akLsBqX61ZhXnws', 'id': 'UExpZl9qcjdwUFpBQVpEenF4YXRXaUplY2xsYmZSWk1BWC41NkI0NEY2RDEwNTU3Q0M2', 'snippet': {'publishedAt': '2016-09-06T06:23:40Z', 'channelId': 'UCUj6rrhMTR9pipbAWBAMvUQ', 'title': '【투 더 문】 #1 달에 가고 싶은 영감님 (To the moon)', 'description': "♨'투 더 문' 처음부터 보기: http://goo.gl/M59Wtb\n보시다가 재밌는 부분은 댓글로 제보해 주시면 하이라이트 영상에 반영하겠습니다. 감사합니다.\n\n2016년 9월 2일 방송분\n침착맨 유투부 구독하기: http://goo.gl/wzc7Ib\n침착맨 트위치 방송: http://www.twitch.tv/zilioner", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RdlAPHwfkFQ/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/RdlAPHwfkFQ/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/RdlAPHwfkFQ/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/RdlAPHwfkFQ/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/RdlAPHwfkFQ/maxresdefault.jpg', 'width': 128
# ...
